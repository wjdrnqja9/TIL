# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdrnqja9/TIL/blob/main/deep_learning/1_Traditional_ML_(TF_IDF_%26_XGBoost).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### ❗️ 본 실습자료는 저작권법에 의거하여 **본 교육 外 배포/게시/공개/공유를 금합니다.**

# %% [markdown]
# <br>
#
# ## ❗️ 전체 실습에서 GoogleDrive & Colab을 활용합니다.
#
# - **colab_data** 폴더를 통째로 Google Drive에 업로드해주세요. (Colab Notebooks 폴더 옆)
# - Colab 에서 실습 파일들을 실행해주세요.

# %% [markdown]
# <br>
# <br>
#
# # 0. Install & import libraries

# %%
# !pip install konlpy==0.5.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy==0.5.2
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 8.0 MB/s
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy==0.5.2) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.2 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 69.0 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy==0.5.2) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy==0.5.2) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy==0.5.2) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy==0.5.2) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy==0.5.2) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy==0.5.2) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy==0.5.2) (3.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy==0.5.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy==0.5.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy==0.5.2) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy==0.5.2) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy==0.5.2) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.4.0 beautifulsoup4-4.6.0 colorama-0.4.5 konlpy-0.5.2

# %%
import konlpy
import sklearn
print(konlpy.__version__) # 0.5.2
print(sklearn.__version__) # 1.0.2
# Out:
# 0.5.2
# 1.0.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import re
import tqdm
import urllib.request
from collections import Counter

from konlpy.tag import Okt 

# [ konlpy.tag.Mecab ] 사용 희망 시, 아래의 코드를 통해 먼저 설치 진행 후 import를 진행해주셔야 합니다 (리눅스 & Colab만 가능)
# (한국어 형태소 분석기 성능 비교 @ https://j.mp/3wTHrkw & https://j.mp/3rrSgJm)

# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# from konlpy.tag import Mecab

# %% [markdown]
# <br>
# <br>
#
# # 1. Load the data

# %%
# Download the original data directly from github by using [ urlretrieve() ]
urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt", filename="ratings_total.txt")

# - Original source @ https://github.com/bab2min/corpus
# - 네이버 쇼핑(https://shopping.naver.com/)에서 2020.06~2020.07 기간에 걸쳐 20만 건의 리뷰 텍스트를 별점(1~5점)과 함께 수집 
# - 3점에 해당하는 데이터를 삭제한 후, 1~2점(부정) & 4~5점(긍정) 데이터의 비율이 1:1에 가깝게 맞춰지도록 샘플링 진행
# Out:
# ('ratings_total.txt', <http.client.HTTPMessage at 0x7ff3c6250850>)

# %%
# or you can upload the file to Colab with the following codes.

# from google.colab import files
# uploaded = files.upload() # Please upload the file named "naver_shopping.txt"

# %%
reviews_df = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])

print('전체 리뷰 수 :',len(reviews_df)) # 전체 리뷰 수 (중복 리뷰가 존재할 수 있음)

reviews_df.head(3)
# Out:
# 전체 리뷰 수 : 200000
#    ratings                                            reviews
# 0        5                                            배공빠르고 굿
# 1        2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2        5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...

# %% [markdown]
# <br>
# <br>
#
# # 2. Preprocess the data

# %% [markdown]
# ### 1) 중복 체크 & 중복 제거

# %%
reviews_df[ reviews_df['reviews'].duplicated(keep=False) == True ].sort_values('reviews') # keep=False : Mark all duplicates as `True`. (생략 시 중복된 항목 중 하나만 꺼내줍니다.)
# Out:
#         ratings                     reviews
# 8731          4                 2022년까지 넉넉함
# 10958         5                 2022년까지 넉넉함
# 95928         2           3년 동안 꾸준히 쓰는데 좋아요
# 137154        1           3년 동안 꾸준히 쓰는데 좋아요
# 89900         4             가격에 비해 가성비 좋습니다
# ...         ...                         ...
# 18075         1                  크기가 너무 작아요
# 56290         2  한사이즈 크게 주문하세요 스판기 없고 통풍 안됨
# 184478        1  한사이즈 크게 주문하세요 스판기 없고 통풍 안됨
# 195539        4               효과가 있는지 모르겠어요
# 31088         1               효과가 있는지 모르겠어요
#
# [184 rows x 2 columns]

# %%
reviews_df = reviews_df.drop_duplicates('reviews') 
reviews_df = reviews_df.reset_index(drop=True)

print('중복 제거 후 전체 리뷰 수 :', len(reviews_df))
# Out:
# 중복 제거 후 전체 리뷰 수 : 199908

# %% [markdown]
# <br>
#
# ### 2) 리뷰 별점을 기준으로 하여 Label 열 생성 (긍정 == 1, 부정 == 0)

# %%
reviews_df['label'] = reviews_df['ratings'].apply(lambda x : 1 if x > 3 else 0)

reviews_df.head(3)
# Out:
#    ratings                                            reviews  label
# 0        5                                            배공빠르고 굿      1
# 1        2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고      0
# 2        5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...      1

# %%
print(reviews_df['label'].value_counts() / len(reviews_df))

# 클래스 불균형 X
# Out:
# 0    0.500005
# 1    0.499995
# Name: label, dtype: float64

# %% [markdown]
# <br>
#
# ### 3) 형태소 분석 (+ 불용어 제거)

# %%
# [ whitespaces, 숫자, 영문 알파벳, 한글(+자모음) ]이 아닌 것을 공백으로 치환 (특수문자 제거)
                    # 띄어쓰기 / 영문대소문자 / 숫자 / 하늘 자,모음도 아닌 것 = 특수문자 캐치
text_test = re.sub("[^\s0-9a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣]", "", '장마라 그런가!!! 달지않아요 ^^') # sub(pattern, repl, string, ...)
text_test
# Out:
# '장마라 그런가 달지않아요 '

# %%
def tokenize_and_stemming(sentence, tokenizer):

    sentence = re.sub("[^\s0-9a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣]", "", sentence) 
    
    raw_pos_tagged = tokenizer.pos(sentence, stem=True) # POS Tagging with stemming

    sentence_tokenized = []
    for token, pos in raw_pos_tagged: # ex) word <- ('서울', 'Noun')
        # pos 기준 제거 대상 : ["Josa", "Eomi", "Punctuation", "Foreign", "Number", "Suffix", "Determiner"]
        # 리뷰 텍스트 상 형태소의 순서를 고려하는 경우 의미를 갖게 됨 : "VerbPrefix" (잘/안/못), "Conjunction"(하지만/그러나/그리고), "KoreanParticle"(ㅋㅋㅋ/ㅎㅎㅎ/ㅠㅠ)
        if (len(token) != 1) & (pos in ["Noun", "VerbPrefix", "Verb", "Adverb", "Adjective", "Conjunction", "KoreanParticle"]):
            sentence_tokenized.append(token)  

    return sentence_tokenized

# %%
# Colab 기준 10분 가량 소요됩니다.

okt = Okt()
tokenized_sentences = []

for sentence in tqdm.tqdm(reviews_df['reviews']):
    try:
        tokenized_sentences.append(tokenize_and_stemming(sentence, okt))
    except:
        print("Error occured at :", sentence)
        tokenized_sentences.append([])

reviews_df['reviews'] = tokenized_sentences

# reviews_df['reviews'] = reviews_df['reviews'].apply(tokenize_and_stemming, tokenizer=okt) # tqdm 미사용 시 1줄로도 적용 가능
# Out:
# 100%|██████████| 199908/199908 [11:24<00:00, 291.85it/s]

# %%
reviews_df[reviews_df['label'] == 1]['reviews'][0]
# Out:
# ['배공', '빠르다']

# %%
type(reviews_df[reviews_df['label'] == 1]['reviews'][0])
# Out:
# list

# %%
# 긍정 리뷰에 많이 포함되었던 형태소 체크

tokens_positive = []

for tokens_list in reviews_df[reviews_df['label'] == 1]['reviews']:
    tokens_positive.extend(tokens_list)
    # tokens_positive.extend(eval(tokens_list)) 
    # eval()의 역할 : "['편하다', '가성', '최고']" (str) -> ['편하다', '가성', '최고'] (list)

tokens_positive_counted = Counter(tokens_positive)
tokens_positive_counted.most_common(20)
# Out:
# [('좋다', 49791),
#  ('하다', 44499),
#  ('배송', 16281),
#  ('자다', 13484),
#  ('너무', 12169),
#  ('재다', 11753),
#  ('있다', 11610),
#  ('먹다', 11404),
#  ('같다', 10511),
#  ('빠르다', 10254),
#  ('구매', 9529),
#  ('사용', 7208),
#  ('가격', 6687),
#  ('이다', 6677),
#  ('만족하다', 6515),
#  ('맛있다', 6342),
#  ('쓰다', 6147),
#  ('사다', 6107),
#  ('되다', 5849),
#  ('보다', 5655)]

# %%
# 부정 리뷰에 많이 포함되었던 형태소 체크

tokens_negative = []

for tokens_list in reviews_df[reviews_df['label'] == 0]['reviews']:
    tokens_negative.extend(tokens_list)
    # tokens_negative.extend(eval(tokens_list)) 
    # eval()의 역할 : "['편하다', '가성', '최고']" (str) -> ['편하다', '가성', '최고'] (list)

tokens_negative_counted = Counter(tokens_negative)
tokens_negative_counted.most_common(20)
# Out:
# [('하다', 52669),
#  ('너무', 17582),
#  ('배송', 12194),
#  ('같다', 11903),
#  ('없다', 11414),
#  ('좋다', 11195),
#  ('있다', 10712),
#  ('않다', 10640),
#  ('그냥', 10507),
#  ('오다', 9377),
#  ('이다', 8168),
#  ('쓰다', 7904),
#  ('되다', 7722),
#  ('별로', 7436),
#  ('사다', 7332),
#  ('아니다', 7160),
#  ('보다', 6809),
#  ('자다', 6746),
#  ('제품', 6733),
#  ('생각', 6588)]

# %% [markdown]
# <br>
#
# ### 4) 전처리 적용 후 데이터 중간 저장 @ Google Drive

# %%
# Colab 런타임 초기화를 대비해 구글드라이브에 현재까지 처리를 마친 데이터를 저장

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# 1) Save
data_path = '/gdrive/MyDrive/colab_data/temp_data/' 

# 구글 드라이브 내 "data_path" 경로의 폴더가 존재하지 않을 시 새로이 생성
if not os.path.exists(data_path): 
    os.makedirs(data_path)

reviews_df.to_csv(data_path + 'data_reviews_tokenized.csv', encoding='utf-8', index=False)


# 2) Load
# data_path = '/gdrive/MyDrive/colab_data/temp_data/' 
# reviews_df = pd.read_csv(data_path + 'data_reviews_tokenized.csv', encoding='utf-8')
# reviews_df['reviews'] = reviews_df['reviews'].apply(eval)
# reviews_df

# %% [markdown]
# <br>
# <br>
#
# # 3. Modeling - Traditional ML (XGBoost)

# %%
from sklearn import model_selection
from sklearn.feature_extraction.text import TfidfVectorizer # CountVectorizer
from sklearn.metrics import accuracy_score

from xgboost import XGBClassifier # version : 0.90

# %%
train_x, test_x, train_y, test_y = model_selection.train_test_split(reviews_df['reviews'], reviews_df['label'], 
                                                                    test_size=0.3, 
                                                                    random_state=42) 

# 별도로 stratify 파라미터 값을 지정하지 않아도 자동으로 클래스 비율이 유지됨
# print(train_y.value_counts() / len(train_y))

# %%
# 각각의 문서에 해당하는 데이터가 단순 문자열(ex. '물건이 정말 좋습니다')이 아니라, 
# 각 단어들에 대한 문자열을 모은 하나의 리스트(ex. ['물건이', '정말', '좋습니다'])로 주어질 경우,
# 아래와 같이 Vectorizer를 설정하여 들어온 리스트를 그대로 받아들이도록 해주고 (tokenizer & token_pattern) 
# 단순 문자열이 아니기에 발생하는 .lower() 함수(Vectorizer 내부에서 작동됨)의 에러를 막아줍니다.

# 아래 TfidfVectorizer() 에서 tokenizer 파라미터에게 lambda 함수를 넣어줄 수도 있으나, 이 경우 추후 vectorizer의 저장이 불가합니다. (https://j.mp/3y6cjjg)
def list_to_list(doc):
    return doc

vectorizer = TfidfVectorizer(tokenizer=list_to_list, token_pattern=None, lowercase=False) # CountVectorizer 적용 시 아주 약간 성능 저하 (88.15% -> 88.02%)
vectorizer.fit(train_x)

train_x_vector = vectorizer.transform(train_x) # .toarray() 함수를 연달아 적용하면 np.array 형태로 만들어진 행렬을 확인할 수 있으나, RAM이 초과되어 Colab이 초기화됩니다. 
test_x_vector = vectorizer.transform(test_x)

# %%
model_xgb = XGBClassifier(max_depth=4, 
                          n_estimators=1500, # 500 -> 86 / 1000 -> 87 / 1500 -> 88
                          random_state=42) 

model_xgb.fit(train_x_vector, train_y, 
              early_stopping_rounds=10, # check for no improvement in log-loss(evaluation metric이 여러가지인 경우 마지막 metric이 기준) over the 10 epochs
              eval_metric=["error", "logloss"], # error == binary classification error, logloss == cross-entropy <- + merror, auc, rmse, mae, etc @ https://j.mp/3eTsUiF
              eval_set=[(train_x_vector, train_y), (test_x_vector, test_y)])
# Out:
# [0]	validation_0-error:0.282746	validation_0-logloss:0.671445	validation_1-error:0.280743	validation_1-logloss:0.671355
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-error:0.280988	validation_0-logloss:0.653575	validation_1-error:0.279559	validation_1-logloss:0.653469
# [2]	validation_0-error:0.280916	validation_0-logloss:0.638626	validation_1-error:0.279426	validation_1-logloss:0.63858
# [3]	validation_0-error:0.280294	validation_0-logloss:0.625823	validation_1-error:0.279209	validation_1-logloss:0.625684
# [4]	validation_0-error:0.280059	validation_0-logloss:0.614731	validation_1-error:0.279009	validation_1-logloss:0.614782
# [5]	validation_0-error:0.278272	validation_0-logloss:0.604918	validation_1-error:0.277358	validation_1-logloss:0.604956
# [6]	validation_0-error:0.277236	validation_0-logloss:0.596404	validation_1-error:0.276358	validation_1-logloss:0.59642
# [7]	validation_0-error:0.275599	validation_0-logloss:0.588659	validation_1-error:0.274757	validation_1-logloss:0.58871
# [8]	validation_0-error:0.271004	validation_0-logloss:0.581271	validation_1-error:0.271189	validation_1-logloss:0.581492
# [9]	validation_0-error:0.270754	validation_0-logloss:0.574997	validation_1-error:0.271072	validation_1-logloss:0.575384
# [10]	validation_0-error:0.263444	validation_0-logloss:0.569173	validation_1-error:0.264319	validation_1-logloss:0.569615
# [11]	validation_0-error:0.26543	validation_0-logloss:0.563953	validation_1-error:0.265236	validation_1-logloss:0.564356
# [12]	validation_0-error:0.261157	validation_0-logloss:0.558856	validation_1-error:0.261384	validation_1-logloss:0.559347
# [13]	validation_0-error:0.260893	validation_0-logloss:0.554514	validation_1-error:0.260817	validation_1-logloss:0.55493
# [14]	validation_0-error:0.260635	validation_0-logloss:0.550314	validation_1-error:0.261034	validation_1-logloss:0.550795
# [15]	validation_0-error:0.25942	validation_0-logloss:0.546316	validation_1-error:0.259884	validation_1-logloss:0.546704
# [16]	validation_0-error:0.252689	validation_0-logloss:0.542762	validation_1-error:0.252464	validation_1-logloss:0.543288
# [17]	validation_0-error:0.25216	validation_0-logloss:0.539307	validation_1-error:0.252197	validation_1-logloss:0.5399
# [18]	validation_0-error:0.248415	validation_0-logloss:0.535995	validation_1-error:0.248679	validation_1-logloss:0.536596
# [19]	validation_0-error:0.239683	validation_0-logloss:0.532906	validation_1-error:0.240325	validation_1-logloss:0.533604
# [20]	validation_0-error:0.238889	validation_0-logloss:0.529828	validation_1-error:0.239124	validation_1-logloss:0.530593
# [21]	validation_0-error:0.233458	validation_0-logloss:0.526832	validation_1-error:0.233522	validation_1-logloss:0.527531
# [22]	validation_0-error:0.23741	validation_0-logloss:0.523835	validation_1-error:0.23804	validation_1-logloss:0.524637
# [23]	validation_0-error:0.231815	validation_0-logloss:0.521179	validation_1-error:0.231854	validation_1-logloss:0.521999
# [24]	validation_0-error:0.227627	validation_0-logloss:0.518579	validation_1-error:0.228186	validation_1-logloss:0.519483
# [25]	validation_0-error:0.229971	validation_0-logloss:0.516014	validation_1-error:0.23067	validation_1-logloss:0.517032
# [26]	validation_0-error:0.225033	validation_0-logloss:0.513503	validation_1-error:0.225552	validation_1-logloss:0.514509
# [27]	validation_0-error:0.224626	validation_0-logloss:0.510995	validation_1-error:0.225135	validation_1-logloss:0.512026
# [28]	validation_0-error:0.223975	validation_0-logloss:0.508169	validation_1-error:0.224601	validation_1-logloss:0.509122
# [29]	validation_0-error:0.215321	validation_0-logloss:0.505522	validation_1-error:0.216614	validation_1-logloss:0.506587
# [30]	validation_0-error:0.214342	validation_0-logloss:0.503286	validation_1-error:0.215647	validation_1-logloss:0.504331
# [31]	validation_0-error:0.211034	validation_0-logloss:0.501171	validation_1-error:0.212896	validation_1-logloss:0.502331
# [32]	validation_0-error:0.208404	validation_0-logloss:0.499154	validation_1-error:0.210611	validation_1-logloss:0.500251
# [33]	validation_0-error:0.209998	validation_0-logloss:0.497124	validation_1-error:0.211812	validation_1-logloss:0.49827
# [34]	validation_0-error:0.207468	validation_0-logloss:0.495158	validation_1-error:0.209494	validation_1-logloss:0.496274
# [35]	validation_0-error:0.202944	validation_0-logloss:0.493042	validation_1-error:0.204058	validation_1-logloss:0.494169
# [36]	validation_0-error:0.202565	validation_0-logloss:0.491208	validation_1-error:0.203792	validation_1-logloss:0.49245
# [37]	validation_0-error:0.202087	validation_0-logloss:0.489294	validation_1-error:0.203008	validation_1-logloss:0.490561
# [38]	validation_0-error:0.201672	validation_0-logloss:0.487425	validation_1-error:0.202391	validation_1-logloss:0.488753
# [39]	validation_0-error:0.201101	validation_0-logloss:0.485709	validation_1-error:0.201891	validation_1-logloss:0.487079
# [40]	validation_0-error:0.198249	validation_0-logloss:0.483978	validation_1-error:0.199206	validation_1-logloss:0.485473
# [41]	validation_0-error:0.195712	validation_0-logloss:0.482132	validation_1-error:0.197072	validation_1-logloss:0.483765
# [42]	validation_0-error:0.195384	validation_0-logloss:0.480074	validation_1-error:0.197072	validation_1-logloss:0.481688
# [43]	validation_0-error:0.195755	validation_0-logloss:0.478286	validation_1-error:0.197039	validation_1-logloss:0.480008
# [44]	validation_0-error:0.195148	validation_0-logloss:0.476715	validation_1-error:0.196638	validation_1-logloss:0.478391
# [45]	validation_0-error:0.194748	validation_0-logloss:0.475164	validation_1-error:0.196238	validation_1-logloss:0.476784
# [46]	validation_0-error:0.193876	validation_0-logloss:0.473667	validation_1-error:0.195955	validation_1-logloss:0.475325
# [47]	validation_0-error:0.194097	validation_0-logloss:0.472143	validation_1-error:0.195705	validation_1-logloss:0.473881
# [48]	validation_0-error:0.193526	validation_0-logloss:0.470454	validation_1-error:0.195705	validation_1-logloss:0.472111
# [49]	validation_0-error:0.193533	validation_0-logloss:0.469066	validation_1-error:0.195405	validation_1-logloss:0.470817
# [50]	validation_0-error:0.192111	validation_0-logloss:0.46766	validation_1-error:0.194204	validation_1-logloss:0.469516
# [51]	validation_0-error:0.19136	validation_0-logloss:0.466324	validation_1-error:0.193754	validation_1-logloss:0.468172
# [52]	validation_0-error:0.189174	validation_0-logloss:0.464966	validation_1-error:0.191886	validation_1-logloss:0.466949
# [53]	validation_0-error:0.188959	validation_0-logloss:0.463544	validation_1-error:0.191286	validation_1-logloss:0.465546
# [54]	validation_0-error:0.188788	validation_0-logloss:0.462282	validation_1-error:0.191186	validation_1-logloss:0.464281
# [55]	validation_0-error:0.188495	validation_0-logloss:0.460996	validation_1-error:0.190819	validation_1-logloss:0.462985
# [56]	validation_0-error:0.18783	validation_0-logloss:0.459744	validation_1-error:0.190486	validation_1-logloss:0.461794
# [57]	validation_0-error:0.187952	validation_0-logloss:0.458358	validation_1-error:0.190669	validation_1-logloss:0.460359
# [58]	validation_0-error:0.187358	validation_0-logloss:0.457166	validation_1-error:0.190152	validation_1-logloss:0.459206
# [59]	validation_0-error:0.184671	validation_0-logloss:0.4559	validation_1-error:0.187734	validation_1-logloss:0.457986
# [60]	validation_0-error:0.184328	validation_0-logloss:0.454704	validation_1-error:0.187118	validation_1-logloss:0.456779
# [61]	validation_0-error:0.183642	validation_0-logloss:0.453537	validation_1-error:0.186451	validation_1-logloss:0.455601
# [62]	validation_0-error:0.183328	validation_0-logloss:0.452353	validation_1-error:0.186267	validation_1-logloss:0.454541
# [63]	validation_0-error:0.183364	validation_0-logloss:0.451193	validation_1-error:0.186484	validation_1-logloss:0.453425
# [64]	validation_0-error:0.185543	validation_0-logloss:0.450084	validation_1-error:0.187985	validation_1-logloss:0.452385
# [65]	validation_0-error:0.185064	validation_0-logloss:0.449043	validation_1-error:0.187601	validation_1-logloss:0.45134
# [66]	validation_0-error:0.182456	validation_0-logloss:0.447994	validation_1-error:0.185383	validation_1-logloss:0.450321
# [67]	validation_0-error:0.184078	validation_0-logloss:0.446899	validation_1-error:0.187034	validation_1-logloss:0.449234
# [68]	validation_0-error:0.184078	validation_0-logloss:0.445902	validation_1-error:0.186917	validation_1-logloss:0.448312
# [69]	validation_0-error:0.18375	validation_0-logloss:0.444921	validation_1-error:0.186667	validation_1-logloss:0.44736
# [70]	validation_0-error:0.181177	validation_0-logloss:0.443923	validation_1-error:0.1842	validation_1-logloss:0.446359
# [71]	validation_0-error:0.183271	validation_0-logloss:0.442948	validation_1-error:0.185817	validation_1-logloss:0.445344
# [72]	validation_0-error:0.180841	validation_0-logloss:0.442045	validation_1-error:0.183549	validation_1-logloss:0.444422
# [73]	validation_0-error:0.180412	validation_0-logloss:0.441091	validation_1-error:0.182966	validation_1-logloss:0.443447
# [74]	validation_0-error:0.178026	validation_0-logloss:0.440064	validation_1-error:0.181081	validation_1-logloss:0.442495
# [75]	validation_0-error:0.177532	validation_0-logloss:0.439052	validation_1-error:0.180515	validation_1-logloss:0.441503
# [76]	validation_0-error:0.17919	validation_0-logloss:0.438086	validation_1-error:0.182315	validation_1-logloss:0.440585
# [77]	validation_0-error:0.176939	validation_0-logloss:0.436926	validation_1-error:0.180098	validation_1-logloss:0.43946
# [78]	validation_0-error:0.176696	validation_0-logloss:0.435973	validation_1-error:0.180098	validation_1-logloss:0.438541
# [79]	validation_0-error:0.17601	validation_0-logloss:0.435019	validation_1-error:0.179698	validation_1-logloss:0.437678
# [80]	validation_0-error:0.17586	validation_0-logloss:0.43411	validation_1-error:0.179581	validation_1-logloss:0.436839
# [81]	validation_0-error:0.177025	validation_0-logloss:0.433271	validation_1-error:0.180231	validation_1-logloss:0.435987
# [82]	validation_0-error:0.175589	validation_0-logloss:0.432366	validation_1-error:0.17888	validation_1-logloss:0.435091
# [83]	validation_0-error:0.175467	validation_0-logloss:0.431562	validation_1-error:0.178714	validation_1-logloss:0.434351
# [84]	validation_0-error:0.175546	validation_0-logloss:0.430756	validation_1-error:0.178597	validation_1-logloss:0.4336
# [85]	validation_0-error:0.173859	validation_0-logloss:0.429909	validation_1-error:0.177363	validation_1-logloss:0.432791
# [86]	validation_0-error:0.173523	validation_0-logloss:0.429126	validation_1-error:0.177146	validation_1-logloss:0.432038
# [87]	validation_0-error:0.17338	validation_0-logloss:0.428195	validation_1-error:0.176913	validation_1-logloss:0.431092
# [88]	validation_0-error:0.173309	validation_0-logloss:0.427415	validation_1-error:0.176629	validation_1-logloss:0.430311
# [89]	validation_0-error:0.172744	validation_0-logloss:0.426679	validation_1-error:0.175729	validation_1-logloss:0.429575
# [90]	validation_0-error:0.171051	validation_0-logloss:0.425862	validation_1-error:0.174012	validation_1-logloss:0.428834
# [91]	validation_0-error:0.170915	validation_0-logloss:0.425142	validation_1-error:0.173995	validation_1-logloss:0.428152
# [92]	validation_0-error:0.170629	validation_0-logloss:0.424369	validation_1-error:0.173595	validation_1-logloss:0.427379
# [93]	validation_0-error:0.170915	validation_0-logloss:0.42353	validation_1-error:0.173862	validation_1-logloss:0.426582
# [94]	validation_0-error:0.170472	validation_0-logloss:0.422551	validation_1-error:0.173845	validation_1-logloss:0.425722
# [95]	validation_0-error:0.169729	validation_0-logloss:0.42185	validation_1-error:0.172944	validation_1-logloss:0.425044
# [96]	validation_0-error:0.169557	validation_0-logloss:0.421084	validation_1-error:0.173128	validation_1-logloss:0.424294
# [97]	validation_0-error:0.1693	validation_0-logloss:0.420406	validation_1-error:0.172811	validation_1-logloss:0.423575
# [98]	validation_0-error:0.168921	validation_0-logloss:0.419686	validation_1-error:0.172511	validation_1-logloss:0.42279
# [99]	validation_0-error:0.169014	validation_0-logloss:0.419012	validation_1-error:0.172494	validation_1-logloss:0.422141
# [100]	validation_0-error:0.168607	validation_0-logloss:0.418323	validation_1-error:0.172261	validation_1-logloss:0.421525
# [101]	validation_0-error:0.168614	validation_0-logloss:0.417661	validation_1-error:0.172094	validation_1-logloss:0.420904
# [102]	validation_0-error:0.167628	validation_0-logloss:0.416903	validation_1-error:0.171227	validation_1-logloss:0.420232
# [103]	validation_0-error:0.167392	validation_0-logloss:0.416285	validation_1-error:0.171044	validation_1-logloss:0.419659
# [104]	validation_0-error:0.167085	validation_0-logloss:0.415604	validation_1-error:0.170593	validation_1-logloss:0.419042
# [105]	validation_0-error:0.166928	validation_0-logloss:0.414985	validation_1-error:0.170427	validation_1-logloss:0.418504
# [106]	validation_0-error:0.166506	validation_0-logloss:0.414342	validation_1-error:0.17001	validation_1-logloss:0.417957
# [107]	validation_0-error:0.166427	validation_0-logloss:0.413712	validation_1-error:0.169976	validation_1-logloss:0.417323
# [108]	validation_0-error:0.166234	validation_0-logloss:0.413022	validation_1-error:0.16976	validation_1-logloss:0.416653
# [109]	validation_0-error:0.166099	validation_0-logloss:0.412395	validation_1-error:0.169593	validation_1-logloss:0.416013
# [110]	validation_0-error:0.165934	validation_0-logloss:0.411804	validation_1-error:0.16936	validation_1-logloss:0.41543
# [111]	validation_0-error:0.165927	validation_0-logloss:0.411197	validation_1-error:0.169276	validation_1-logloss:0.414878
# [112]	validation_0-error:0.165648	validation_0-logloss:0.410622	validation_1-error:0.169043	validation_1-logloss:0.414288
# [113]	validation_0-error:0.16542	validation_0-logloss:0.410035	validation_1-error:0.168876	validation_1-logloss:0.413692
# [114]	validation_0-error:0.165212	validation_0-logloss:0.409429	validation_1-error:0.168576	validation_1-logloss:0.413077
# [115]	validation_0-error:0.165062	validation_0-logloss:0.408862	validation_1-error:0.168359	validation_1-logloss:0.412506
# [116]	validation_0-error:0.165005	validation_0-logloss:0.408294	validation_1-error:0.168276	validation_1-logloss:0.411905
# [117]	validation_0-error:0.164248	validation_0-logloss:0.407736	validation_1-error:0.167409	validation_1-logloss:0.411375
# [118]	validation_0-error:0.164062	validation_0-logloss:0.407133	validation_1-error:0.167442	validation_1-logloss:0.410831
# [119]	validation_0-error:0.163662	validation_0-logloss:0.406558	validation_1-error:0.167059	validation_1-logloss:0.410349
# [120]	validation_0-error:0.163454	validation_0-logloss:0.40591	validation_1-error:0.166758	validation_1-logloss:0.409758
# [121]	validation_0-error:0.163347	validation_0-logloss:0.405389	validation_1-error:0.166742	validation_1-logloss:0.409309
# [122]	validation_0-error:0.163204	validation_0-logloss:0.404895	validation_1-error:0.166592	validation_1-logloss:0.408836
# [123]	validation_0-error:0.162976	validation_0-logloss:0.404335	validation_1-error:0.166325	validation_1-logloss:0.408353
# [124]	validation_0-error:0.163033	validation_0-logloss:0.403799	validation_1-error:0.166458	validation_1-logloss:0.407837
# [125]	validation_0-error:0.162668	validation_0-logloss:0.403278	validation_1-error:0.166125	validation_1-logloss:0.407369
# [126]	validation_0-error:0.162518	validation_0-logloss:0.402781	validation_1-error:0.166041	validation_1-logloss:0.406926
# [127]	validation_0-error:0.162132	validation_0-logloss:0.40219	validation_1-error:0.166008	validation_1-logloss:0.406353
# [128]	validation_0-error:0.162147	validation_0-logloss:0.401664	validation_1-error:0.165741	validation_1-logloss:0.405865
# [129]	validation_0-error:0.162204	validation_0-logloss:0.401145	validation_1-error:0.165508	validation_1-logloss:0.405345
# [130]	validation_0-error:0.161897	validation_0-logloss:0.400674	validation_1-error:0.165291	validation_1-logloss:0.404861
# [131]	validation_0-error:0.161682	validation_0-logloss:0.400166	validation_1-error:0.165174	validation_1-logloss:0.404358
# [132]	validation_0-error:0.161432	validation_0-logloss:0.399624	validation_1-error:0.164991	validation_1-logloss:0.403801
# [133]	validation_0-error:0.161396	validation_0-logloss:0.399123	validation_1-error:0.164824	validation_1-logloss:0.403292
# [134]	validation_0-error:0.161125	validation_0-logloss:0.398557	validation_1-error:0.164974	validation_1-logloss:0.402834
# [135]	validation_0-error:0.160753	validation_0-logloss:0.398054	validation_1-error:0.164557	validation_1-logloss:0.402389
# [136]	validation_0-error:0.160617	validation_0-logloss:0.397559	validation_1-error:0.164357	validation_1-logloss:0.401912
# [137]	validation_0-error:0.160189	validation_0-logloss:0.397067	validation_1-error:0.163874	validation_1-logloss:0.401468
# [138]	validation_0-error:0.160489	validation_0-logloss:0.396604	validation_1-error:0.164174	validation_1-logloss:0.401043
# [139]	validation_0-error:0.159667	validation_0-logloss:0.396154	validation_1-error:0.163407	validation_1-logloss:0.400585
# [140]	validation_0-error:0.159667	validation_0-logloss:0.395726	validation_1-error:0.163207	validation_1-logloss:0.400233
# [141]	validation_0-error:0.159331	validation_0-logloss:0.395244	validation_1-error:0.163207	validation_1-logloss:0.399761
# [142]	validation_0-error:0.159224	validation_0-logloss:0.394835	validation_1-error:0.163123	validation_1-logloss:0.399379
# [143]	validation_0-error:0.158588	validation_0-logloss:0.394402	validation_1-error:0.16279	validation_1-logloss:0.398944
# [144]	validation_0-error:0.158888	validation_0-logloss:0.39391	validation_1-error:0.163023	validation_1-logloss:0.398521
# [145]	validation_0-error:0.158588	validation_0-logloss:0.393472	validation_1-error:0.162473	validation_1-logloss:0.39808
# [146]	validation_0-error:0.158424	validation_0-logloss:0.393045	validation_1-error:0.162406	validation_1-logloss:0.397701
# [147]	validation_0-error:0.158145	validation_0-logloss:0.392613	validation_1-error:0.162206	validation_1-logloss:0.397307
# [148]	validation_0-error:0.157973	validation_0-logloss:0.39222	validation_1-error:0.162006	validation_1-logloss:0.396903
# [149]	validation_0-error:0.157645	validation_0-logloss:0.391807	validation_1-error:0.161723	validation_1-logloss:0.396508
# [150]	validation_0-error:0.157037	validation_0-logloss:0.391313	validation_1-error:0.161156	validation_1-logloss:0.396095
# [151]	validation_0-error:0.156787	validation_0-logloss:0.390845	validation_1-error:0.161039	validation_1-logloss:0.395706
# [152]	validation_0-error:0.156251	validation_0-logloss:0.390388	validation_1-error:0.160572	validation_1-logloss:0.395274
# [153]	validation_0-error:0.156294	validation_0-logloss:0.389947	validation_1-error:0.160606	validation_1-logloss:0.394913
# [154]	validation_0-error:0.155908	validation_0-logloss:0.389524	validation_1-error:0.160355	validation_1-logloss:0.394553
# [155]	validation_0-error:0.15593	validation_0-logloss:0.389143	validation_1-error:0.160205	validation_1-logloss:0.394216
# [156]	validation_0-error:0.155608	validation_0-logloss:0.38877	validation_1-error:0.159939	validation_1-logloss:0.393858
# [157]	validation_0-error:0.155722	validation_0-logloss:0.38837	validation_1-error:0.159939	validation_1-logloss:0.393443
# [158]	validation_0-error:0.155529	validation_0-logloss:0.387959	validation_1-error:0.159772	validation_1-logloss:0.393061
# [159]	validation_0-error:0.155336	validation_0-logloss:0.387556	validation_1-error:0.159722	validation_1-logloss:0.392721
# [160]	validation_0-error:0.155315	validation_0-logloss:0.387175	validation_1-error:0.159555	validation_1-logloss:0.392395
# [161]	validation_0-error:0.155315	validation_0-logloss:0.386762	validation_1-error:0.159572	validation_1-logloss:0.391972
# [162]	validation_0-error:0.155279	validation_0-logloss:0.386394	validation_1-error:0.159522	validation_1-logloss:0.391625
# [163]	validation_0-error:0.155322	validation_0-logloss:0.38593	validation_1-error:0.159488	validation_1-logloss:0.391216
# [164]	validation_0-error:0.155308	validation_0-logloss:0.385499	validation_1-error:0.159255	validation_1-logloss:0.390822
# [165]	validation_0-error:0.154879	validation_0-logloss:0.385139	validation_1-error:0.158888	validation_1-logloss:0.390493
# [166]	validation_0-error:0.154815	validation_0-logloss:0.384792	validation_1-error:0.158905	validation_1-logloss:0.390197
# [167]	validation_0-error:0.154829	validation_0-logloss:0.38444	validation_1-error:0.158855	validation_1-logloss:0.389849
# [168]	validation_0-error:0.154643	validation_0-logloss:0.384091	validation_1-error:0.158655	validation_1-logloss:0.389491
# [169]	validation_0-error:0.154858	validation_0-logloss:0.38372	validation_1-error:0.158988	validation_1-logloss:0.389172
# [170]	validation_0-error:0.154708	validation_0-logloss:0.383324	validation_1-error:0.159038	validation_1-logloss:0.388813
# [171]	validation_0-error:0.154429	validation_0-logloss:0.382939	validation_1-error:0.158738	validation_1-logloss:0.388447
# [172]	validation_0-error:0.15435	validation_0-logloss:0.38254	validation_1-error:0.158671	validation_1-logloss:0.388098
# [173]	validation_0-error:0.1542	validation_0-logloss:0.382185	validation_1-error:0.158521	validation_1-logloss:0.387756
# [174]	validation_0-error:0.154107	validation_0-logloss:0.381839	validation_1-error:0.158371	validation_1-logloss:0.387449
# [175]	validation_0-error:0.153864	validation_0-logloss:0.381489	validation_1-error:0.158205	validation_1-logloss:0.387106
# [176]	validation_0-error:0.153157	validation_0-logloss:0.381098	validation_1-error:0.157521	validation_1-logloss:0.386723
# [177]	validation_0-error:0.153035	validation_0-logloss:0.380752	validation_1-error:0.157237	validation_1-logloss:0.386412
# [178]	validation_0-error:0.152778	validation_0-logloss:0.38037	validation_1-error:0.156904	validation_1-logloss:0.386095
# [179]	validation_0-error:0.152585	validation_0-logloss:0.380045	validation_1-error:0.156721	validation_1-logloss:0.3858
# [180]	validation_0-error:0.152249	validation_0-logloss:0.379591	validation_1-error:0.15662	validation_1-logloss:0.385361
# [181]	validation_0-error:0.152099	validation_0-logloss:0.37928	validation_1-error:0.156504	validation_1-logloss:0.385074
# [182]	validation_0-error:0.151892	validation_0-logloss:0.378933	validation_1-error:0.156304	validation_1-logloss:0.384739
# [183]	validation_0-error:0.151813	validation_0-logloss:0.3786	validation_1-error:0.156237	validation_1-logloss:0.384412
# [184]	validation_0-error:0.151542	validation_0-logloss:0.378292	validation_1-error:0.156054	validation_1-logloss:0.384149
# [185]	validation_0-error:0.151527	validation_0-logloss:0.377982	validation_1-error:0.15602	validation_1-logloss:0.383869
# [186]	validation_0-error:0.151456	validation_0-logloss:0.377628	validation_1-error:0.155903	validation_1-logloss:0.383569
# [187]	validation_0-error:0.151227	validation_0-logloss:0.377287	validation_1-error:0.15587	validation_1-logloss:0.383259
# [188]	validation_0-error:0.150927	validation_0-logloss:0.376961	validation_1-error:0.155453	validation_1-logloss:0.382907
# [189]	validation_0-error:0.150856	validation_0-logloss:0.376669	validation_1-error:0.155353	validation_1-logloss:0.382619
# [190]	validation_0-error:0.150756	validation_0-logloss:0.376364	validation_1-error:0.15537	validation_1-logloss:0.382357
# [191]	validation_0-error:0.15077	validation_0-logloss:0.376071	validation_1-error:0.155337	validation_1-logloss:0.382061
# [192]	validation_0-error:0.150627	validation_0-logloss:0.375735	validation_1-error:0.155303	validation_1-logloss:0.381775
# [193]	validation_0-error:0.150577	validation_0-logloss:0.375418	validation_1-error:0.155153	validation_1-logloss:0.381503
# [194]	validation_0-error:0.150484	validation_0-logloss:0.375124	validation_1-error:0.155053	validation_1-logloss:0.381245
# [195]	validation_0-error:0.150091	validation_0-logloss:0.374762	validation_1-error:0.15487	validation_1-logloss:0.38098
# [196]	validation_0-error:0.15002	validation_0-logloss:0.374436	validation_1-error:0.155003	validation_1-logloss:0.380702
# [197]	validation_0-error:0.149691	validation_0-logloss:0.374134	validation_1-error:0.154653	validation_1-logloss:0.38043
# [198]	validation_0-error:0.149584	validation_0-logloss:0.373839	validation_1-error:0.15462	validation_1-logloss:0.380174
# [199]	validation_0-error:0.149705	validation_0-logloss:0.373503	validation_1-error:0.154836	validation_1-logloss:0.379868
# [200]	validation_0-error:0.149419	validation_0-logloss:0.373218	validation_1-error:0.154503	validation_1-logloss:0.379622
# [201]	validation_0-error:0.149448	validation_0-logloss:0.372814	validation_1-error:0.154603	validation_1-logloss:0.379235
# [202]	validation_0-error:0.149555	validation_0-logloss:0.372385	validation_1-error:0.15467	validation_1-logloss:0.378862
# [203]	validation_0-error:0.149326	validation_0-logloss:0.372061	validation_1-error:0.15457	validation_1-logloss:0.378626
# [204]	validation_0-error:0.149241	validation_0-logloss:0.371771	validation_1-error:0.154636	validation_1-logloss:0.378391
# [205]	validation_0-error:0.149226	validation_0-logloss:0.371413	validation_1-error:0.154436	validation_1-logloss:0.37809
# [206]	validation_0-error:0.148948	validation_0-logloss:0.371143	validation_1-error:0.154353	validation_1-logloss:0.37785
# [207]	validation_0-error:0.149026	validation_0-logloss:0.37086	validation_1-error:0.154219	validation_1-logloss:0.377584
# [208]	validation_0-error:0.148855	validation_0-logloss:0.370571	validation_1-error:0.154186	validation_1-logloss:0.377294
# [209]	validation_0-error:0.14874	validation_0-logloss:0.370293	validation_1-error:0.154069	validation_1-logloss:0.376998
# [210]	validation_0-error:0.148605	validation_0-logloss:0.370002	validation_1-error:0.154119	validation_1-logloss:0.376746
# [211]	validation_0-error:0.14834	validation_0-logloss:0.36971	validation_1-error:0.153919	validation_1-logloss:0.376523
# [212]	validation_0-error:0.14824	validation_0-logloss:0.369416	validation_1-error:0.153719	validation_1-logloss:0.376232
# [213]	validation_0-error:0.148083	validation_0-logloss:0.369156	validation_1-error:0.153469	validation_1-logloss:0.375971
# [214]	validation_0-error:0.147761	validation_0-logloss:0.368896	validation_1-error:0.153086	validation_1-logloss:0.375721
# [215]	validation_0-error:0.147583	validation_0-logloss:0.368603	validation_1-error:0.153019	validation_1-logloss:0.375432
# [216]	validation_0-error:0.147376	validation_0-logloss:0.368295	validation_1-error:0.152919	validation_1-logloss:0.375154
# [217]	validation_0-error:0.147361	validation_0-logloss:0.368036	validation_1-error:0.152986	validation_1-logloss:0.374909
# [218]	validation_0-error:0.147233	validation_0-logloss:0.367783	validation_1-error:0.152919	validation_1-logloss:0.374701
# [219]	validation_0-error:0.147118	validation_0-logloss:0.367531	validation_1-error:0.152819	validation_1-logloss:0.374503
# [220]	validation_0-error:0.147154	validation_0-logloss:0.367257	validation_1-error:0.152685	validation_1-logloss:0.374209
# [221]	validation_0-error:0.147054	validation_0-logloss:0.366999	validation_1-error:0.152635	validation_1-logloss:0.373986
# [222]	validation_0-error:0.147054	validation_0-logloss:0.366732	validation_1-error:0.152535	validation_1-logloss:0.373751
# [223]	validation_0-error:0.146954	validation_0-logloss:0.366482	validation_1-error:0.152435	validation_1-logloss:0.373495
# [224]	validation_0-error:0.146682	validation_0-logloss:0.366246	validation_1-error:0.152152	validation_1-logloss:0.373291
# [225]	validation_0-error:0.146718	validation_0-logloss:0.365979	validation_1-error:0.152219	validation_1-logloss:0.373037
# [226]	validation_0-error:0.146397	validation_0-logloss:0.365711	validation_1-error:0.151852	validation_1-logloss:0.372786
# [227]	validation_0-error:0.146554	validation_0-logloss:0.365409	validation_1-error:0.151935	validation_1-logloss:0.372528
# [228]	validation_0-error:0.146468	validation_0-logloss:0.365154	validation_1-error:0.151818	validation_1-logloss:0.372284
# [229]	validation_0-error:0.146275	validation_0-logloss:0.364908	validation_1-error:0.151818	validation_1-logloss:0.372073
# [230]	validation_0-error:0.146218	validation_0-logloss:0.364653	validation_1-error:0.151702	validation_1-logloss:0.37182
# [231]	validation_0-error:0.145896	validation_0-logloss:0.364405	validation_1-error:0.151451	validation_1-logloss:0.371629
# [232]	validation_0-error:0.145789	validation_0-logloss:0.364152	validation_1-error:0.151418	validation_1-logloss:0.371381
# [233]	validation_0-error:0.145668	validation_0-logloss:0.36391	validation_1-error:0.151301	validation_1-logloss:0.371164
# [234]	validation_0-error:0.145568	validation_0-logloss:0.363658	validation_1-error:0.151235	validation_1-logloss:0.37092
# [235]	validation_0-error:0.145489	validation_0-logloss:0.363409	validation_1-error:0.151151	validation_1-logloss:0.370725
# [236]	validation_0-error:0.145153	validation_0-logloss:0.363155	validation_1-error:0.151001	validation_1-logloss:0.370519
# [237]	validation_0-error:0.14511	validation_0-logloss:0.362917	validation_1-error:0.150968	validation_1-logloss:0.370295
# [238]	validation_0-error:0.144824	validation_0-logloss:0.362686	validation_1-error:0.150734	validation_1-logloss:0.370071
# [239]	validation_0-error:0.144803	validation_0-logloss:0.362443	validation_1-error:0.150785	validation_1-logloss:0.369883
# [240]	validation_0-error:0.144553	validation_0-logloss:0.362172	validation_1-error:0.150451	validation_1-logloss:0.369613
# [241]	validation_0-error:0.144424	validation_0-logloss:0.361898	validation_1-error:0.150351	validation_1-logloss:0.369421
# [242]	validation_0-error:0.144346	validation_0-logloss:0.361664	validation_1-error:0.150301	validation_1-logloss:0.369205
# [243]	validation_0-error:0.14421	validation_0-logloss:0.361418	validation_1-error:0.150301	validation_1-logloss:0.368967
# [244]	validation_0-error:0.143774	validation_0-logloss:0.361161	validation_1-error:0.149834	validation_1-logloss:0.368755
# [245]	validation_0-error:0.143645	validation_0-logloss:0.360931	validation_1-error:0.149717	validation_1-logloss:0.368553
# [246]	validation_0-error:0.143409	validation_0-logloss:0.36064	validation_1-error:0.149534	validation_1-logloss:0.368284
# [247]	validation_0-error:0.143324	validation_0-logloss:0.360419	validation_1-error:0.149451	validation_1-logloss:0.368126
# [248]	validation_0-error:0.142916	validation_0-logloss:0.36015	validation_1-error:0.149434	validation_1-logloss:0.367868
# [249]	validation_0-error:0.142873	validation_0-logloss:0.359928	validation_1-error:0.149351	validation_1-logloss:0.367671
# [250]	validation_0-error:0.143059	validation_0-logloss:0.35971	validation_1-error:0.149117	validation_1-logloss:0.367449
# [251]	validation_0-error:0.142974	validation_0-logloss:0.35948	validation_1-error:0.149	validation_1-logloss:0.367274
# [252]	validation_0-error:0.142781	validation_0-logloss:0.359268	validation_1-error:0.148767	validation_1-logloss:0.367068
# [253]	validation_0-error:0.142966	validation_0-logloss:0.358995	validation_1-error:0.148984	validation_1-logloss:0.366828
# [254]	validation_0-error:0.142866	validation_0-logloss:0.358768	validation_1-error:0.148867	validation_1-logloss:0.366621
# [255]	validation_0-error:0.142859	validation_0-logloss:0.358455	validation_1-error:0.1489	validation_1-logloss:0.366379
# [256]	validation_0-error:0.142731	validation_0-logloss:0.358245	validation_1-error:0.148884	validation_1-logloss:0.366187
# [257]	validation_0-error:0.142595	validation_0-logloss:0.358002	validation_1-error:0.14875	validation_1-logloss:0.365989
# [258]	validation_0-error:0.142509	validation_0-logloss:0.357771	validation_1-error:0.148734	validation_1-logloss:0.365802
# [259]	validation_0-error:0.142445	validation_0-logloss:0.357522	validation_1-error:0.14875	validation_1-logloss:0.36557
# [260]	validation_0-error:0.142373	validation_0-logloss:0.357298	validation_1-error:0.14865	validation_1-logloss:0.365398
# [261]	validation_0-error:0.142316	validation_0-logloss:0.35709	validation_1-error:0.148584	validation_1-logloss:0.365224
# [262]	validation_0-error:0.142345	validation_0-logloss:0.356868	validation_1-error:0.14855	validation_1-logloss:0.365018
# [263]	validation_0-error:0.142209	validation_0-logloss:0.35664	validation_1-error:0.148534	validation_1-logloss:0.364807
# [264]	validation_0-error:0.142195	validation_0-logloss:0.356426	validation_1-error:0.148467	validation_1-logloss:0.364623
# [265]	validation_0-error:0.142202	validation_0-logloss:0.356212	validation_1-error:0.14835	validation_1-logloss:0.364427
# [266]	validation_0-error:0.142073	validation_0-logloss:0.356027	validation_1-error:0.1484	validation_1-logloss:0.364233
# [267]	validation_0-error:0.142037	validation_0-logloss:0.355715	validation_1-error:0.14825	validation_1-logloss:0.36396
# [268]	validation_0-error:0.141952	validation_0-logloss:0.355462	validation_1-error:0.148133	validation_1-logloss:0.363779
# [269]	validation_0-error:0.141923	validation_0-logloss:0.355204	validation_1-error:0.148383	validation_1-logloss:0.363629
# [270]	validation_0-error:0.141766	validation_0-logloss:0.355015	validation_1-error:0.1483	validation_1-logloss:0.363401
# [271]	validation_0-error:0.141673	validation_0-logloss:0.354821	validation_1-error:0.1482	validation_1-logloss:0.363247
# [272]	validation_0-error:0.141537	validation_0-logloss:0.354611	validation_1-error:0.148167	validation_1-logloss:0.36309
# [273]	validation_0-error:0.14148	validation_0-logloss:0.354397	validation_1-error:0.14815	validation_1-logloss:0.362901
# [274]	validation_0-error:0.141459	validation_0-logloss:0.354205	validation_1-error:0.147967	validation_1-logloss:0.362718
# [275]	validation_0-error:0.141409	validation_0-logloss:0.354014	validation_1-error:0.147917	validation_1-logloss:0.362563
# [276]	validation_0-error:0.141323	validation_0-logloss:0.353827	validation_1-error:0.147833	validation_1-logloss:0.362387
# [277]	validation_0-error:0.140858	validation_0-logloss:0.353583	validation_1-error:0.1474	validation_1-logloss:0.362202
# [278]	validation_0-error:0.140801	validation_0-logloss:0.353374	validation_1-error:0.147333	validation_1-logloss:0.362058
# [279]	validation_0-error:0.140665	validation_0-logloss:0.353171	validation_1-error:0.147283	validation_1-logloss:0.361866
# [280]	validation_0-error:0.140708	validation_0-logloss:0.35295	validation_1-error:0.14735	validation_1-logloss:0.3617
# [281]	validation_0-error:0.140487	validation_0-logloss:0.352728	validation_1-error:0.147233	validation_1-logloss:0.36155
# [282]	validation_0-error:0.140429	validation_0-logloss:0.352526	validation_1-error:0.147216	validation_1-logloss:0.361343
# [283]	validation_0-error:0.140158	validation_0-logloss:0.352313	validation_1-error:0.146966	validation_1-logloss:0.361132
# [284]	validation_0-error:0.140094	validation_0-logloss:0.352074	validation_1-error:0.146966	validation_1-logloss:0.360936
# [285]	validation_0-error:0.139994	validation_0-logloss:0.351863	validation_1-error:0.146783	validation_1-logloss:0.360753
# [286]	validation_0-error:0.139901	validation_0-logloss:0.35168	validation_1-error:0.146716	validation_1-logloss:0.360619
# [287]	validation_0-error:0.139779	validation_0-logloss:0.351459	validation_1-error:0.146766	validation_1-logloss:0.360431
# [288]	validation_0-error:0.139672	validation_0-logloss:0.351269	validation_1-error:0.146783	validation_1-logloss:0.360264
# [289]	validation_0-error:0.139543	validation_0-logloss:0.351096	validation_1-error:0.146733	validation_1-logloss:0.36012
# [290]	validation_0-error:0.139529	validation_0-logloss:0.350886	validation_1-error:0.146783	validation_1-logloss:0.359957
# [291]	validation_0-error:0.139493	validation_0-logloss:0.350689	validation_1-error:0.146683	validation_1-logloss:0.359799
# [292]	validation_0-error:0.139365	validation_0-logloss:0.3505	validation_1-error:0.146683	validation_1-logloss:0.359617
# [293]	validation_0-error:0.139222	validation_0-logloss:0.350302	validation_1-error:0.146766	validation_1-logloss:0.359467
# [294]	validation_0-error:0.139179	validation_0-logloss:0.35013	validation_1-error:0.146733	validation_1-logloss:0.359285
# [295]	validation_0-error:0.139065	validation_0-logloss:0.349916	validation_1-error:0.146699	validation_1-logloss:0.359087
# [296]	validation_0-error:0.138886	validation_0-logloss:0.34973	validation_1-error:0.146549	validation_1-logloss:0.358901
# [297]	validation_0-error:0.138757	validation_0-logloss:0.349545	validation_1-error:0.146499	validation_1-logloss:0.358769
# [298]	validation_0-error:0.138614	validation_0-logloss:0.349359	validation_1-error:0.146583	validation_1-logloss:0.358566
# [299]	validation_0-error:0.13855	validation_0-logloss:0.34918	validation_1-error:0.146366	validation_1-logloss:0.358412
# [300]	validation_0-error:0.138443	validation_0-logloss:0.349001	validation_1-error:0.146182	validation_1-logloss:0.358255
# [301]	validation_0-error:0.138443	validation_0-logloss:0.348799	validation_1-error:0.146099	validation_1-logloss:0.358078
# [302]	validation_0-error:0.138278	validation_0-logloss:0.348606	validation_1-error:0.145982	validation_1-logloss:0.357929
# [303]	validation_0-error:0.138514	validation_0-logloss:0.348388	validation_1-error:0.146049	validation_1-logloss:0.357767
# [304]	validation_0-error:0.1384	validation_0-logloss:0.348175	validation_1-error:0.145916	validation_1-logloss:0.357551
# [305]	validation_0-error:0.138221	validation_0-logloss:0.34799	validation_1-error:0.146016	validation_1-logloss:0.357355
# [306]	validation_0-error:0.13815	validation_0-logloss:0.347811	validation_1-error:0.145899	validation_1-logloss:0.357183
# [307]	validation_0-error:0.1383	validation_0-logloss:0.347623	validation_1-error:0.145699	validation_1-logloss:0.357013
# [308]	validation_0-error:0.138236	validation_0-logloss:0.347454	validation_1-error:0.145682	validation_1-logloss:0.356886
# [309]	validation_0-error:0.13825	validation_0-logloss:0.347271	validation_1-error:0.145532	validation_1-logloss:0.356717
# [310]	validation_0-error:0.138178	validation_0-logloss:0.347111	validation_1-error:0.145532	validation_1-logloss:0.356594
# [311]	validation_0-error:0.138121	validation_0-logloss:0.346943	validation_1-error:0.145549	validation_1-logloss:0.35645
# [312]	validation_0-error:0.138014	validation_0-logloss:0.346767	validation_1-error:0.145465	validation_1-logloss:0.356285
# [313]	validation_0-error:0.137928	validation_0-logloss:0.346556	validation_1-error:0.145415	validation_1-logloss:0.356087
# [314]	validation_0-error:0.1379	validation_0-logloss:0.346371	validation_1-error:0.145499	validation_1-logloss:0.355955
# [315]	validation_0-error:0.137814	validation_0-logloss:0.346215	validation_1-error:0.145399	validation_1-logloss:0.355811
# [316]	validation_0-error:0.137735	validation_0-logloss:0.346037	validation_1-error:0.145232	validation_1-logloss:0.355632
# [317]	validation_0-error:0.137607	validation_0-logloss:0.34587	validation_1-error:0.145165	validation_1-logloss:0.355496
# [318]	validation_0-error:0.137271	validation_0-logloss:0.345702	validation_1-error:0.145132	validation_1-logloss:0.355352
# [319]	validation_0-error:0.137192	validation_0-logloss:0.345523	validation_1-error:0.145082	validation_1-logloss:0.355191
# [320]	validation_0-error:0.137121	validation_0-logloss:0.345372	validation_1-error:0.144982	validation_1-logloss:0.355055
# [321]	validation_0-error:0.137099	validation_0-logloss:0.345196	validation_1-error:0.144982	validation_1-logloss:0.354891
# [322]	validation_0-error:0.136928	validation_0-logloss:0.344968	validation_1-error:0.144798	validation_1-logloss:0.354692
# [323]	validation_0-error:0.136871	validation_0-logloss:0.344788	validation_1-error:0.144598	validation_1-logloss:0.35453
# [324]	validation_0-error:0.136671	validation_0-logloss:0.344622	validation_1-error:0.144465	validation_1-logloss:0.354383
# [325]	validation_0-error:0.136649	validation_0-logloss:0.344428	validation_1-error:0.144498	validation_1-logloss:0.354189
# [326]	validation_0-error:0.136506	validation_0-logloss:0.344263	validation_1-error:0.144415	validation_1-logloss:0.354065
# [327]	validation_0-error:0.136428	validation_0-logloss:0.344099	validation_1-error:0.144315	validation_1-logloss:0.353927
# [328]	validation_0-error:0.136363	validation_0-logloss:0.343932	validation_1-error:0.144248	validation_1-logloss:0.353787
# [329]	validation_0-error:0.136306	validation_0-logloss:0.343775	validation_1-error:0.144182	validation_1-logloss:0.353643
# [330]	validation_0-error:0.13627	validation_0-logloss:0.343607	validation_1-error:0.144115	validation_1-logloss:0.353489
# [331]	validation_0-error:0.136049	validation_0-logloss:0.343454	validation_1-error:0.144082	validation_1-logloss:0.353373
# [332]	validation_0-error:0.136163	validation_0-logloss:0.343302	validation_1-error:0.144031	validation_1-logloss:0.353227
# [333]	validation_0-error:0.135977	validation_0-logloss:0.343137	validation_1-error:0.143948	validation_1-logloss:0.353073
# [334]	validation_0-error:0.13577	validation_0-logloss:0.342936	validation_1-error:0.143748	validation_1-logloss:0.352898
# [335]	validation_0-error:0.13567	validation_0-logloss:0.342764	validation_1-error:0.143581	validation_1-logloss:0.352741
# [336]	validation_0-error:0.135606	validation_0-logloss:0.342594	validation_1-error:0.143581	validation_1-logloss:0.352602
# [337]	validation_0-error:0.135499	validation_0-logloss:0.342424	validation_1-error:0.143581	validation_1-logloss:0.352451
# [338]	validation_0-error:0.135399	validation_0-logloss:0.342275	validation_1-error:0.143515	validation_1-logloss:0.352314
# [339]	validation_0-error:0.135363	validation_0-logloss:0.342112	validation_1-error:0.143481	validation_1-logloss:0.352183
# [340]	validation_0-error:0.135306	validation_0-logloss:0.341937	validation_1-error:0.143164	validation_1-logloss:0.35206
# [341]	validation_0-error:0.135263	validation_0-logloss:0.341772	validation_1-error:0.143014	validation_1-logloss:0.351917
# [342]	validation_0-error:0.135098	validation_0-logloss:0.341613	validation_1-error:0.142931	validation_1-logloss:0.351776
# [343]	validation_0-error:0.135041	validation_0-logloss:0.341461	validation_1-error:0.142798	validation_1-logloss:0.351621
# [344]	validation_0-error:0.134948	validation_0-logloss:0.341303	validation_1-error:0.142881	validation_1-logloss:0.351505
# [345]	validation_0-error:0.134848	validation_0-logloss:0.341147	validation_1-error:0.142748	validation_1-logloss:0.351358
# [346]	validation_0-error:0.134827	validation_0-logloss:0.340996	validation_1-error:0.142731	validation_1-logloss:0.351232
# [347]	validation_0-error:0.134634	validation_0-logloss:0.340832	validation_1-error:0.142698	validation_1-logloss:0.351093
# [348]	validation_0-error:0.134648	validation_0-logloss:0.34067	validation_1-error:0.142648	validation_1-logloss:0.350964
# [349]	validation_0-error:0.134555	validation_0-logloss:0.340492	validation_1-error:0.142664	validation_1-logloss:0.350827
# [350]	validation_0-error:0.134391	validation_0-logloss:0.340334	validation_1-error:0.142664	validation_1-logloss:0.350689
# [351]	validation_0-error:0.134362	validation_0-logloss:0.340154	validation_1-error:0.142564	validation_1-logloss:0.350532
# [352]	validation_0-error:0.134298	validation_0-logloss:0.340002	validation_1-error:0.142614	validation_1-logloss:0.350414
# [353]	validation_0-error:0.134177	validation_0-logloss:0.339852	validation_1-error:0.142514	validation_1-logloss:0.350274
# [354]	validation_0-error:0.134119	validation_0-logloss:0.339699	validation_1-error:0.142531	validation_1-logloss:0.35016
# [355]	validation_0-error:0.133919	validation_0-logloss:0.339534	validation_1-error:0.142464	validation_1-logloss:0.350037
# [356]	validation_0-error:0.133726	validation_0-logloss:0.339389	validation_1-error:0.142214	validation_1-logloss:0.349919
# [357]	validation_0-error:0.133569	validation_0-logloss:0.339225	validation_1-error:0.142231	validation_1-logloss:0.349799
# [358]	validation_0-error:0.133483	validation_0-logloss:0.339077	validation_1-error:0.142164	validation_1-logloss:0.349655
# [359]	validation_0-error:0.133526	validation_0-logloss:0.338922	validation_1-error:0.142381	validation_1-logloss:0.349524
# [360]	validation_0-error:0.133398	validation_0-logloss:0.338777	validation_1-error:0.142114	validation_1-logloss:0.349378
# [361]	validation_0-error:0.133412	validation_0-logloss:0.338635	validation_1-error:0.142181	validation_1-logloss:0.349234
# [362]	validation_0-error:0.133369	validation_0-logloss:0.338475	validation_1-error:0.142114	validation_1-logloss:0.349085
# [363]	validation_0-error:0.133283	validation_0-logloss:0.338314	validation_1-error:0.142081	validation_1-logloss:0.348962
# [364]	validation_0-error:0.133283	validation_0-logloss:0.338172	validation_1-error:0.142031	validation_1-logloss:0.348874
# [365]	validation_0-error:0.133176	validation_0-logloss:0.338021	validation_1-error:0.141897	validation_1-logloss:0.34875
# [366]	validation_0-error:0.133133	validation_0-logloss:0.337881	validation_1-error:0.141881	validation_1-logloss:0.34863
# [367]	validation_0-error:0.133033	validation_0-logloss:0.337692	validation_1-error:0.141847	validation_1-logloss:0.348487
# [368]	validation_0-error:0.133033	validation_0-logloss:0.337548	validation_1-error:0.141864	validation_1-logloss:0.348378
# [369]	validation_0-error:0.132969	validation_0-logloss:0.337409	validation_1-error:0.141764	validation_1-logloss:0.348254
# [370]	validation_0-error:0.13294	validation_0-logloss:0.337246	validation_1-error:0.141764	validation_1-logloss:0.348132
# [371]	validation_0-error:0.13279	validation_0-logloss:0.337106	validation_1-error:0.141614	validation_1-logloss:0.348021
# [372]	validation_0-error:0.132733	validation_0-logloss:0.336979	validation_1-error:0.14153	validation_1-logloss:0.347905
# [373]	validation_0-error:0.132647	validation_0-logloss:0.336852	validation_1-error:0.141464	validation_1-logloss:0.347798
# [374]	validation_0-error:0.132604	validation_0-logloss:0.336712	validation_1-error:0.14143	validation_1-logloss:0.347718
# [375]	validation_0-error:0.132576	validation_0-logloss:0.336557	validation_1-error:0.141364	validation_1-logloss:0.347597
# [376]	validation_0-error:0.132554	validation_0-logloss:0.336406	validation_1-error:0.141297	validation_1-logloss:0.347463
# [377]	validation_0-error:0.132512	validation_0-logloss:0.336261	validation_1-error:0.141297	validation_1-logloss:0.347343
# [378]	validation_0-error:0.132433	validation_0-logloss:0.336116	validation_1-error:0.141247	validation_1-logloss:0.347227
# [379]	validation_0-error:0.132247	validation_0-logloss:0.335972	validation_1-error:0.14103	validation_1-logloss:0.347107
# [380]	validation_0-error:0.132311	validation_0-logloss:0.335828	validation_1-error:0.14113	validation_1-logloss:0.346991
# [381]	validation_0-error:0.13224	validation_0-logloss:0.335607	validation_1-error:0.14103	validation_1-logloss:0.346807
# [382]	validation_0-error:0.13199	validation_0-logloss:0.335473	validation_1-error:0.140647	validation_1-logloss:0.346701
# [383]	validation_0-error:0.131911	validation_0-logloss:0.335335	validation_1-error:0.140647	validation_1-logloss:0.346607
# [384]	validation_0-error:0.131833	validation_0-logloss:0.335212	validation_1-error:0.140663	validation_1-logloss:0.346519
# [385]	validation_0-error:0.131847	validation_0-logloss:0.335033	validation_1-error:0.14093	validation_1-logloss:0.346364
# [386]	validation_0-error:0.131825	validation_0-logloss:0.3349	validation_1-error:0.140763	validation_1-logloss:0.346249
# [387]	validation_0-error:0.131761	validation_0-logloss:0.33475	validation_1-error:0.14073	validation_1-logloss:0.346142
# [388]	validation_0-error:0.131675	validation_0-logloss:0.33461	validation_1-error:0.14058	validation_1-logloss:0.346029
# [389]	validation_0-error:0.131511	validation_0-logloss:0.334464	validation_1-error:0.14048	validation_1-logloss:0.345907
# [390]	validation_0-error:0.13149	validation_0-logloss:0.334316	validation_1-error:0.14043	validation_1-logloss:0.345804
# [391]	validation_0-error:0.131482	validation_0-logloss:0.334194	validation_1-error:0.140246	validation_1-logloss:0.345703
# [392]	validation_0-error:0.13139	validation_0-logloss:0.334067	validation_1-error:0.140313	validation_1-logloss:0.345605
# [393]	validation_0-error:0.131261	validation_0-logloss:0.333908	validation_1-error:0.140213	validation_1-logloss:0.345468
# ...
# [1370]	validation_0-error:0.103234	validation_0-logloss:0.271368	validation_1-error:0.119721	validation_1-logloss:0.301373
# [1371]	validation_0-error:0.103212	validation_0-logloss:0.27133	validation_1-error:0.119721	validation_1-logloss:0.301348
# [1372]	validation_0-error:0.103191	validation_0-logloss:0.271306	validation_1-error:0.119704	validation_1-logloss:0.301333
# [1373]	validation_0-error:0.103169	validation_0-logloss:0.271279	validation_1-error:0.119704	validation_1-logloss:0.301323
# [1374]	validation_0-error:0.103105	validation_0-logloss:0.271253	validation_1-error:0.119704	validation_1-logloss:0.301312
# [1375]	validation_0-error:0.103112	validation_0-logloss:0.271229	validation_1-error:0.119671	validation_1-logloss:0.301294
# [1376]	validation_0-error:0.103112	validation_0-logloss:0.271199	validation_1-error:0.119687	validation_1-logloss:0.30126
# [1377]	validation_0-error:0.103112	validation_0-logloss:0.27116	validation_1-error:0.119671	validation_1-logloss:0.301228
# [1378]	validation_0-error:0.103134	validation_0-logloss:0.27112	validation_1-error:0.11962	validation_1-logloss:0.301224
# [1379]	validation_0-error:0.103119	validation_0-logloss:0.271075	validation_1-error:0.11957	validation_1-logloss:0.301194
# [1380]	validation_0-error:0.103091	validation_0-logloss:0.271028	validation_1-error:0.11957	validation_1-logloss:0.301181
# [1381]	validation_0-error:0.103069	validation_0-logloss:0.270989	validation_1-error:0.11962	validation_1-logloss:0.301151
# [1382]	validation_0-error:0.103091	validation_0-logloss:0.270943	validation_1-error:0.119604	validation_1-logloss:0.301138
# [1383]	validation_0-error:0.103069	validation_0-logloss:0.270915	validation_1-error:0.11957	validation_1-logloss:0.301118
# [1384]	validation_0-error:0.103062	validation_0-logloss:0.270878	validation_1-error:0.11962	validation_1-logloss:0.301104
# [1385]	validation_0-error:0.103034	validation_0-logloss:0.270849	validation_1-error:0.119604	validation_1-logloss:0.301094
# [1386]	validation_0-error:0.103019	validation_0-logloss:0.270826	validation_1-error:0.119587	validation_1-logloss:0.301071
# [1387]	validation_0-error:0.102991	validation_0-logloss:0.270787	validation_1-error:0.119587	validation_1-logloss:0.301051
# [1388]	validation_0-error:0.102955	validation_0-logloss:0.270758	validation_1-error:0.11957	validation_1-logloss:0.301023
# [1389]	validation_0-error:0.102934	validation_0-logloss:0.270732	validation_1-error:0.119554	validation_1-logloss:0.301012
# [1390]	validation_0-error:0.102934	validation_0-logloss:0.270704	validation_1-error:0.11957	validation_1-logloss:0.301001
# [1391]	validation_0-error:0.102948	validation_0-logloss:0.270675	validation_1-error:0.119604	validation_1-logloss:0.300986
# [1392]	validation_0-error:0.102926	validation_0-logloss:0.270649	validation_1-error:0.119537	validation_1-logloss:0.300969
# [1393]	validation_0-error:0.102919	validation_0-logloss:0.270611	validation_1-error:0.11947	validation_1-logloss:0.300943
# [1394]	validation_0-error:0.102912	validation_0-logloss:0.270578	validation_1-error:0.119437	validation_1-logloss:0.300924
# [1395]	validation_0-error:0.102883	validation_0-logloss:0.270543	validation_1-error:0.11947	validation_1-logloss:0.300909
# [1396]	validation_0-error:0.102883	validation_0-logloss:0.270514	validation_1-error:0.119454	validation_1-logloss:0.300883
# [1397]	validation_0-error:0.102848	validation_0-logloss:0.270481	validation_1-error:0.11947	validation_1-logloss:0.300864
# [1398]	validation_0-error:0.102841	validation_0-logloss:0.270456	validation_1-error:0.119454	validation_1-logloss:0.300845
# [1399]	validation_0-error:0.102812	validation_0-logloss:0.270424	validation_1-error:0.11947	validation_1-logloss:0.300825
# [1400]	validation_0-error:0.102805	validation_0-logloss:0.270393	validation_1-error:0.11947	validation_1-logloss:0.300808
# [1401]	validation_0-error:0.102791	validation_0-logloss:0.270363	validation_1-error:0.119437	validation_1-logloss:0.30079
# [1402]	validation_0-error:0.102741	validation_0-logloss:0.270319	validation_1-error:0.119437	validation_1-logloss:0.300771
# [1403]	validation_0-error:0.102726	validation_0-logloss:0.27029	validation_1-error:0.11942	validation_1-logloss:0.30075
# [1404]	validation_0-error:0.102719	validation_0-logloss:0.270255	validation_1-error:0.119404	validation_1-logloss:0.300727
# [1405]	validation_0-error:0.102712	validation_0-logloss:0.270225	validation_1-error:0.119387	validation_1-logloss:0.300703
# [1406]	validation_0-error:0.102691	validation_0-logloss:0.270201	validation_1-error:0.119404	validation_1-logloss:0.300685
# [1407]	validation_0-error:0.102683	validation_0-logloss:0.270168	validation_1-error:0.119404	validation_1-logloss:0.30065
# [1408]	validation_0-error:0.102662	validation_0-logloss:0.270145	validation_1-error:0.119387	validation_1-logloss:0.300636
# [1409]	validation_0-error:0.102648	validation_0-logloss:0.270115	validation_1-error:0.119404	validation_1-logloss:0.300623
# [1410]	validation_0-error:0.102626	validation_0-logloss:0.270081	validation_1-error:0.119404	validation_1-logloss:0.300605
# [1411]	validation_0-error:0.102605	validation_0-logloss:0.270052	validation_1-error:0.119354	validation_1-logloss:0.300573
# [1412]	validation_0-error:0.102583	validation_0-logloss:0.270017	validation_1-error:0.11932	validation_1-logloss:0.300551
# [1413]	validation_0-error:0.102526	validation_0-logloss:0.269983	validation_1-error:0.11932	validation_1-logloss:0.300532
# [1414]	validation_0-error:0.102519	validation_0-logloss:0.269961	validation_1-error:0.119337	validation_1-logloss:0.300512
# [1415]	validation_0-error:0.102498	validation_0-logloss:0.269905	validation_1-error:0.119304	validation_1-logloss:0.300482
# [1416]	validation_0-error:0.102505	validation_0-logloss:0.269871	validation_1-error:0.119287	validation_1-logloss:0.300468
# [1417]	validation_0-error:0.102498	validation_0-logloss:0.269847	validation_1-error:0.119254	validation_1-logloss:0.300451
# [1418]	validation_0-error:0.102476	validation_0-logloss:0.269821	validation_1-error:0.11927	validation_1-logloss:0.300439
# [1419]	validation_0-error:0.10244	validation_0-logloss:0.269795	validation_1-error:0.119254	validation_1-logloss:0.300426
# [1420]	validation_0-error:0.102419	validation_0-logloss:0.269772	validation_1-error:0.119237	validation_1-logloss:0.300406
# [1421]	validation_0-error:0.102412	validation_0-logloss:0.269746	validation_1-error:0.119237	validation_1-logloss:0.300389
# [1422]	validation_0-error:0.102405	validation_0-logloss:0.26972	validation_1-error:0.119237	validation_1-logloss:0.30037
# [1423]	validation_0-error:0.102426	validation_0-logloss:0.269695	validation_1-error:0.11927	validation_1-logloss:0.300356
# [1424]	validation_0-error:0.102419	validation_0-logloss:0.269663	validation_1-error:0.119254	validation_1-logloss:0.300345
# [1425]	validation_0-error:0.102405	validation_0-logloss:0.26962	validation_1-error:0.119237	validation_1-logloss:0.300335
# [1426]	validation_0-error:0.102383	validation_0-logloss:0.269578	validation_1-error:0.119237	validation_1-logloss:0.300309
# [1427]	validation_0-error:0.102383	validation_0-logloss:0.269552	validation_1-error:0.11922	validation_1-logloss:0.300293
# [1428]	validation_0-error:0.102333	validation_0-logloss:0.269524	validation_1-error:0.119154	validation_1-logloss:0.300281
# [1429]	validation_0-error:0.102269	validation_0-logloss:0.269492	validation_1-error:0.119054	validation_1-logloss:0.300256
# [1430]	validation_0-error:0.102269	validation_0-logloss:0.269463	validation_1-error:0.11902	validation_1-logloss:0.300246
# [1431]	validation_0-error:0.102197	validation_0-logloss:0.269406	validation_1-error:0.119004	validation_1-logloss:0.300223
# [1432]	validation_0-error:0.10219	validation_0-logloss:0.269374	validation_1-error:0.118954	validation_1-logloss:0.3002
# [1433]	validation_0-error:0.10219	validation_0-logloss:0.269349	validation_1-error:0.118954	validation_1-logloss:0.300177
# [1434]	validation_0-error:0.102183	validation_0-logloss:0.26932	validation_1-error:0.118937	validation_1-logloss:0.300151
# [1435]	validation_0-error:0.102147	validation_0-logloss:0.269295	validation_1-error:0.118904	validation_1-logloss:0.300149
# [1436]	validation_0-error:0.102133	validation_0-logloss:0.269274	validation_1-error:0.11892	validation_1-logloss:0.300134
# [1437]	validation_0-error:0.102126	validation_0-logloss:0.26925	validation_1-error:0.118853	validation_1-logloss:0.300106
# [1438]	validation_0-error:0.102112	validation_0-logloss:0.269223	validation_1-error:0.11887	validation_1-logloss:0.300096
# [1439]	validation_0-error:0.102112	validation_0-logloss:0.269194	validation_1-error:0.118853	validation_1-logloss:0.300069
# [1440]	validation_0-error:0.102047	validation_0-logloss:0.269154	validation_1-error:0.118753	validation_1-logloss:0.300058
# [1441]	validation_0-error:0.10204	validation_0-logloss:0.269128	validation_1-error:0.118753	validation_1-logloss:0.300045
# [1442]	validation_0-error:0.102019	validation_0-logloss:0.269095	validation_1-error:0.118703	validation_1-logloss:0.300027
# [1443]	validation_0-error:0.102019	validation_0-logloss:0.269073	validation_1-error:0.118687	validation_1-logloss:0.300019
# [1444]	validation_0-error:0.102026	validation_0-logloss:0.269033	validation_1-error:0.118603	validation_1-logloss:0.299981
# [1445]	validation_0-error:0.102019	validation_0-logloss:0.26899	validation_1-error:0.118587	validation_1-logloss:0.299957
# [1446]	validation_0-error:0.102012	validation_0-logloss:0.268962	validation_1-error:0.118553	validation_1-logloss:0.299945
# [1447]	validation_0-error:0.102033	validation_0-logloss:0.268936	validation_1-error:0.11857	validation_1-logloss:0.299946
# [1448]	validation_0-error:0.102019	validation_0-logloss:0.268905	validation_1-error:0.11857	validation_1-logloss:0.299946
# [1449]	validation_0-error:0.101969	validation_0-logloss:0.268869	validation_1-error:0.118553	validation_1-logloss:0.299918
# [1450]	validation_0-error:0.101933	validation_0-logloss:0.268839	validation_1-error:0.118537	validation_1-logloss:0.299901
# [1451]	validation_0-error:0.101926	validation_0-logloss:0.268802	validation_1-error:0.118503	validation_1-logloss:0.299879
# [1452]	validation_0-error:0.101912	validation_0-logloss:0.268762	validation_1-error:0.118503	validation_1-logloss:0.299853
# [1453]	validation_0-error:0.101919	validation_0-logloss:0.268709	validation_1-error:0.118487	validation_1-logloss:0.299825
# [1454]	validation_0-error:0.101919	validation_0-logloss:0.268683	validation_1-error:0.118437	validation_1-logloss:0.299802
# [1455]	validation_0-error:0.101919	validation_0-logloss:0.268657	validation_1-error:0.118453	validation_1-logloss:0.299787
# [1456]	validation_0-error:0.10189	validation_0-logloss:0.268631	validation_1-error:0.11847	validation_1-logloss:0.299768
# [1457]	validation_0-error:0.101862	validation_0-logloss:0.2686	validation_1-error:0.118503	validation_1-logloss:0.299761
# [1458]	validation_0-error:0.101854	validation_0-logloss:0.268575	validation_1-error:0.11847	validation_1-logloss:0.299743
# [1459]	validation_0-error:0.10184	validation_0-logloss:0.268545	validation_1-error:0.118453	validation_1-logloss:0.299718
# [1460]	validation_0-error:0.101833	validation_0-logloss:0.268524	validation_1-error:0.118453	validation_1-logloss:0.299712
# [1461]	validation_0-error:0.101797	validation_0-logloss:0.268496	validation_1-error:0.11847	validation_1-logloss:0.299711
# [1462]	validation_0-error:0.101783	validation_0-logloss:0.268465	validation_1-error:0.118487	validation_1-logloss:0.299694
# [1463]	validation_0-error:0.101754	validation_0-logloss:0.268435	validation_1-error:0.11862	validation_1-logloss:0.299681
# [1464]	validation_0-error:0.101769	validation_0-logloss:0.268408	validation_1-error:0.118637	validation_1-logloss:0.299671
# [1465]	validation_0-error:0.101804	validation_0-logloss:0.268368	validation_1-error:0.118637	validation_1-logloss:0.299659
# [1466]	validation_0-error:0.10179	validation_0-logloss:0.268338	validation_1-error:0.118653	validation_1-logloss:0.299644
# [1467]	validation_0-error:0.101776	validation_0-logloss:0.268287	validation_1-error:0.118687	validation_1-logloss:0.299595
# [1468]	validation_0-error:0.101776	validation_0-logloss:0.268262	validation_1-error:0.118703	validation_1-logloss:0.299593
# [1469]	validation_0-error:0.101776	validation_0-logloss:0.268234	validation_1-error:0.11867	validation_1-logloss:0.299585
# [1470]	validation_0-error:0.101762	validation_0-logloss:0.268209	validation_1-error:0.118687	validation_1-logloss:0.299569
# [1471]	validation_0-error:0.101747	validation_0-logloss:0.268184	validation_1-error:0.118687	validation_1-logloss:0.299557
# [1472]	validation_0-error:0.101747	validation_0-logloss:0.268142	validation_1-error:0.118637	validation_1-logloss:0.299527
# [1473]	validation_0-error:0.10174	validation_0-logloss:0.268113	validation_1-error:0.118637	validation_1-logloss:0.299512
# [1474]	validation_0-error:0.101733	validation_0-logloss:0.268086	validation_1-error:0.118653	validation_1-logloss:0.299493
# [1475]	validation_0-error:0.101697	validation_0-logloss:0.26806	validation_1-error:0.118637	validation_1-logloss:0.299474
# [1476]	validation_0-error:0.10169	validation_0-logloss:0.268013	validation_1-error:0.118637	validation_1-logloss:0.29946
# [1477]	validation_0-error:0.101704	validation_0-logloss:0.267984	validation_1-error:0.11872	validation_1-logloss:0.299443
# [1478]	validation_0-error:0.101669	validation_0-logloss:0.267958	validation_1-error:0.11877	validation_1-logloss:0.299442
# [1479]	validation_0-error:0.101661	validation_0-logloss:0.267926	validation_1-error:0.118753	validation_1-logloss:0.299429
# [1480]	validation_0-error:0.101633	validation_0-logloss:0.267898	validation_1-error:0.118737	validation_1-logloss:0.29942
# [1481]	validation_0-error:0.101626	validation_0-logloss:0.267873	validation_1-error:0.118737	validation_1-logloss:0.299416
# [1482]	validation_0-error:0.10159	validation_0-logloss:0.267848	validation_1-error:0.118737	validation_1-logloss:0.299403
# [1483]	validation_0-error:0.101561	validation_0-logloss:0.267825	validation_1-error:0.118737	validation_1-logloss:0.29939
# [1484]	validation_0-error:0.101576	validation_0-logloss:0.267802	validation_1-error:0.118703	validation_1-logloss:0.299366
# [1485]	validation_0-error:0.101526	validation_0-logloss:0.267768	validation_1-error:0.118703	validation_1-logloss:0.299344
# [1486]	validation_0-error:0.101526	validation_0-logloss:0.267738	validation_1-error:0.11867	validation_1-logloss:0.299331
# [1487]	validation_0-error:0.101519	validation_0-logloss:0.267713	validation_1-error:0.11867	validation_1-logloss:0.29933
# [1488]	validation_0-error:0.101519	validation_0-logloss:0.267687	validation_1-error:0.11867	validation_1-logloss:0.29932
# [1489]	validation_0-error:0.101504	validation_0-logloss:0.267658	validation_1-error:0.11867	validation_1-logloss:0.299303
# [1490]	validation_0-error:0.101511	validation_0-logloss:0.267627	validation_1-error:0.118653	validation_1-logloss:0.299294
# [1491]	validation_0-error:0.101497	validation_0-logloss:0.267585	validation_1-error:0.118637	validation_1-logloss:0.29926
# [1492]	validation_0-error:0.10149	validation_0-logloss:0.267559	validation_1-error:0.118653	validation_1-logloss:0.299246
# [1493]	validation_0-error:0.101476	validation_0-logloss:0.267532	validation_1-error:0.118587	validation_1-logloss:0.299229
# [1494]	validation_0-error:0.101461	validation_0-logloss:0.267506	validation_1-error:0.11857	validation_1-logloss:0.299214
# [1495]	validation_0-error:0.101433	validation_0-logloss:0.267481	validation_1-error:0.118587	validation_1-logloss:0.299207
# [1496]	validation_0-error:0.101433	validation_0-logloss:0.267446	validation_1-error:0.11857	validation_1-logloss:0.299187
# [1497]	validation_0-error:0.101419	validation_0-logloss:0.267416	validation_1-error:0.11857	validation_1-logloss:0.299167
# [1498]	validation_0-error:0.101411	validation_0-logloss:0.267387	validation_1-error:0.118503	validation_1-logloss:0.299151
# [1499]	validation_0-error:0.10139	validation_0-logloss:0.26736	validation_1-error:0.11847	validation_1-logloss:0.299135
# XGBClassifier(max_depth=4, n_estimators=1500, random_state=42)

# %%
print('Training accuracy :', round(accuracy_score(model_xgb.predict(train_x_vector), train_y), 4))
print('Test accuracy :', round(accuracy_score(model_xgb.predict(test_x_vector), test_y), 4))
# Out:
# Training accuracy : 0.8986
# Test accuracy : 0.8815

# %%
# retrieve performance metrics
results = model_xgb.evals_result() # validation_0 == Training data, validation_1 == Test data
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)

# plot log-loss
fig, ax = plt.subplots(dpi=100, figsize=(10, 5))
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
ax.grid()
plt.ylabel('Log-Loss (Cross-entropy)')
plt.title('XGBoost Log-Loss')
plt.show()

# plot classification-error
fig, ax = plt.subplots(dpi=100, figsize=(10, 5))
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
ax.legend()
ax.grid()
plt.ylabel('Classification-Error')
plt.title('XGBoost Classification-Error')
plt.show()

# %%
# # GridSearch for XGBoost (max_depth & subsample)
# # Use the following codes if needed, it will take too much time.

# model_xgb = XGBClassifier()

# xgb_param_grid = {'max_depth': [3, 5, 7], 
#                   'n_estimators': [100], # 300, 500, 700, 1000
#                   'subsample': [0.6, 0.8, 1.0],
#                   'random_state': [42]}

# xgb_gridcv = model_selection.GridSearchCV(estimator=model_xgb,
#                                           param_grid=xgb_param_grid,
#                                           scoring='accuracy', # roc_auc, neg_log_loss, precision, recall, neg_mean_absolute_error, r2, etc @ https://j.mp/3y79Kx8
#                                           n_jobs=-1, # Number of jobs to run in parallel (-1 means using all processors) @ https://j.mp/3yigAjP
#                                           cv=5,
#                                           refit=True, 
#                                           return_train_score=True, # include training scores (can be computationally expensive)
#                                           verbose=1)
# xgb_gridcv.fit(train_x_vector, train_y)


# best_score = xgb_gridcv.best_score_
# best_row = xgb_gridcv.best_index_

# best_max_depth     = xgb_gridcv.best_params_["max_depth"]
# best_max_subsample = xgb_gridcv.best_params_["subsample"]

# print(best_score, best_row, best_max_depth, best_max_subsample)

# xgb_grid_df = pd.DataFrame(xgb_gridcv.cv_results_)
# xgb_gridcv.loc[:, ['mean_test_score', "params"]]
# # xgb_gridcv[xgb_gridcv['rank_test_score'] == 1]

# %% [markdown]
# <br>
# <br>
#
# # + Model & Vectorizer Save/Load -> Predict on a new sentence

# %% [markdown]
# ### 1) Save the model & vectorizer

# %%
import joblib
from google.colab import drive

drive.mount('/gdrive')

data_path = '/gdrive/MyDrive/colab_data/temp_data/' 
if not os.path.exists(data_path): 
    os.makedirs(data_path)

joblib.dump(model_xgb, data_path+'model_xgb_tfidf_v1.pkl', compress=True) # Model 저장
joblib.dump(vectorizer, data_path+'vectorizer_tfidf.pkl', compress=True) # Vectorizer 저장
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# ['/gdrive/MyDrive/colab_data/temp_data/vectorizer_tfidf.pkl']

# %% [markdown]
# ### 2) Load the model & vectorizer -> Predict on new sentences

# %%
import joblib
from google.colab import drive

drive.mount('/gdrive')
data_path = '/gdrive/MyDrive/colab_data/temp_data/' 

model_xgb = joblib.load(data_path+'model_xgb_tfidf_v1.pkl')
vectorizer = joblib.load(data_path+'vectorizer_tfidf.pkl')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# def tokenize_and_stemming(sentence, tokenizer):

#     sentence = re.sub("[^\s0-9a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣]", "", sentence) 
    
#     raw_pos_tagged = tokenizer.pos(sentence, stem=True) # POS Tagging with stemming

#     sentence_tokenized = []
#     for token, pos in raw_pos_tagged: # ex) word <- ('서울', 'Noun')
#         # pos 기준 제거 대상 : ["Josa", "Eomi", "Punctuation", "Foreign", "Number", "Suffix", "Determiner"]
#         # 리뷰 텍스트 상 형태소의 순서를 고려하는 경우 의미를 갖게 됨 : "VerbPrefix" (잘/안/못), "Conjunction"(하지만/그러나/그리고), "KoreanParticle"(ㅋㅋㅋ/ㅎㅎㅎ/ㅠㅠ)
#         if (len(token) != 1) & (pos in ["Noun", "VerbPrefix", "Verb", "Adverb", "Adjective", "Conjunction", "KoreanParticle"]):
#             sentence_tokenized.append(token)  

#     return sentence_tokenized

# %% [markdown]
# ### Predict on a single sentence

# %%
new_sentence = "아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 엉성하긴 하지만 편하고 가성비 최고예요."

okt = Okt()
tokenized_sentences = []
tokenized_sentences.append(tokenize_and_stemming(new_sentence, okt))

new_sentence_vector = vectorizer.transform(tokenized_sentences) 

print(model_xgb.predict_proba(new_sentence_vector))
print(model_xgb.predict(new_sentence_vector))
# Out:
# [[0.00161898 0.998381  ]]
# [1]

# %% [markdown]
# ### Predict on multiple sentences

# %%
new_sentences = ["아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 엉성하긴 하지만 편하고 가성비 최고예요.",
                "너무 맛있어요! 4명이 먹을거라 넉넉하게 샀다했는데 순식간에 없어집니다! 꼭 드셔보세요!", 
                "후기 좋아서 샀는데 진짜 별로에요... 재질두 비니루같은 재질....", 
                "내용물이 안나와요 ㅜㅜ 무용지물 ㅜㅜ 여러개 샀는데 ㅜㅜ"
                ]

okt = Okt()
tokenized_sentences = []

for sentence in new_sentences:
    tokenized_sentences.append(tokenize_and_stemming(sentence, okt))

new_sentence_vector = vectorizer.transform(tokenized_sentences) 

print(model_xgb.predict_proba(new_sentence_vector))
# Out:
# [[0.00161898 0.998381  ]
#  [0.01568407 0.98431593]
#  [0.81362385 0.18637617]
#  [0.9527507  0.04724932]]
